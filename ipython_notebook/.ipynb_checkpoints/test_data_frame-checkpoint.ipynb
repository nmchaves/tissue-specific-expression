# %%
from collections import Counter
import numpy as np
import pandas as pd
import itertools as its

# %%
def construct_matrix(spec_donors=[],reject_donors=[],donor_sex=None,donor_age=[],spec_tissues=[],reject_tissues=[],
                       top_tissues=None,min_tissue_count=None):
    #     This function builds a numpy matrix and associated data arrays for the specified
    
    #     --Parameters--
    #     spec_donors: Array of donor ID strings to include. Leave blank for all donors.
    #     reject_donors: Array of donor IDs to remove. Leave blank to reject no donors.
    #     donor_sex: '1' for only males, '2' for only females, None (or blank) for all donors.
    #     donor_age: Array of age-decade strings to include, e.g. ['20','30','40']. Leave blank for all donors.
    #     spec_tissues: Array of tissue names to include. Leave blank for all tissues.
    #     reject_tissues: Array of tissue names to remove. Leave blank to reject no tissues.
    #     top_tissues: Number of most commonly sampled tissues to include. Leave blank to include all tissues.
    #     min_tissue_count: Minimum number of samples to include a tissue. Leave blank to include all tissues.

    #     Note: spec_donors and reject_donors are mutually exclusive.
    #     Note: spec_tissues and reject_tissues are mutually exclusive.
    #     Note: top_tissues and min_tissue_count are mutually exclusive.
    
    #     --Returns--
    #     multi_matrix: Numpy matrix of 10,000 rows, column for each included sample
    #     point_ID: Array of donor IDs for each column in multi_matrix
    #     point_sex: Array of donor sex for each column in multi_matrix
    #     point_age: Array of donor age for each column in multi_matrix
    #     point_tissue: Array of tissue type for each column in multi_matrix
    #     point_tissue_group: Array of tissue group (just first term of tissue type) for each column in multi_matrix

    # DONORS BY ID
    if not spec_donors:
        all_donors = open('../data/donors_list.txt')
        donor_list = [ID[0:-1] for ID in all_donors if ID[0:-1] not in reject_donors]
        all_donors.close()
    else:
        donor_list = spec_donors
    # dictionary of donor IDs, and an array that will be [sex,age]
    donor_dict = dict((ID,[]) for ID in donor_list)

    # DONORS BY AGE AND SEX
    donor_info = open('../data/donor_info.txt')
    for line in donor_info:
        # info is [ID,sex,age,death]
        info = line.split('\t')
        if info[0] in donor_list:
            # check sex
            if donor_sex and info[1] != donor_sex:
                del donor_dict[info[0]]
                continue
            else:
                donor_dict[info[0]].append(info[1])
            # check age    
            age = info[2].split('-')[0]
            if donor_age and age not in donor_age:
                del donor_dict[info[0]]
                continue
            else:
                donor_dict[info[0]].append(age)
    donor_info.close()

    # TISSUES BY TYPE AND SAMPLE COUNT
    tissues = Counter()
    for ID in donor_dict.keys():
        metafile = open('../data/Donor_Metadata_Enhanced/donor_meta_'+ID+'.txt')
        headerLines = 4
        lineCounter = 0
        for line in metafile:
            # skip the first four lines of header
            if lineCounter < headerLines:
                lineCounter += 1
                continue 
            # look for tissue type listed in meta file
            tissue = line.split('\t')[1][0:-1]
            if spec_tissues and tissue in spec_tissues:
                tissues[tissue] = tissues.get(tissue,0) + 1
            elif not spec_tissues and tissue not in reject_tissues:
                tissues[tissue] = tissues.get(tissue,0) + 1
        metafile.close()
    if min_tissue_count:
        tissue_list = [key for key,value in tissues.iteritems() if value >= min_tissue_count]
    else:
        tissue_list = [key for key,value in tissues.most_common(top_tissues)]

    # CONSTRUCT MATRIX
    # initialize column (to be removed) and info types
    multi_matrix = np.zeros((10000,1))
    point_ID = []
    point_sex = []
    point_age = []
    point_tissue = []
    point_tissue_group = []
    # metadata on relevant points
    
    for ID in sorted(donor_dict.keys()):
        metafile = open('../data/Donor_Metadata_Enhanced/donor_meta_'+ID+'.txt')
        # column indices for relevant tissues
        # print '../data/Donor_Metadata_Enhanced/donor_meta_'+ID+'.txt'
        columns = []
        column = 0
        headerLines = 4
        lineCounter = 0
        for line in metafile:
            # deal with the first four lines of header
            if lineCounter < headerLines:
                lineCounter += 1
                continue 
            tissue = line.split('\t')[1][0:-1]      
            if tissue in tissue_list:
                columns.append(column)
                point_ID.append(ID)
                point_sex.append(donor_dict[ID][0])
                point_age.append(donor_dict[ID][1])
                point_tissue.append(tissue)
                point_tissue_group.append(tissue.split('-')[0])
            column = column + 1
        metafile.close()
        # get data
        donor_matrix = np.zeros((10000,len(columns)))
        row = 0
        donorfile = open('../data/donor_matrices_fixed/donor_'+ID+'.txt')
        for line in donorfile:
            # from file, take desired tissue columns and put in donor matrix
            values = [line.split('\t')[ind] for ind in columns]
            donor_matrix[row,:] = values
            row = row+1
        donorfile.close()
        # concatenate donor matrices
        multi_matrix = np.concatenate((multi_matrix,donor_matrix),axis=1)
    multi_matrix = np.delete(multi_matrix,0,1)
    
    print 'Matrix constructed with ' + str(multi_matrix.shape[1]) + ' samples!'
    return [multi_matrix, point_ID, point_sex, point_age, point_tissue, point_tissue_group]


# In[ ]:

# %%
multi_matrix, point_ID, point_sex, point_age, point_tissue, point_tissue_group = construct_matrix(spec_donors=['13RTK','13RTJ','X638'])
# Out:
# ../data/Donor_Metadata_Enhanced/donor_meta_R3RS.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_144GM.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_144GL.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_144GO.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_12ZZW.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_XXEK.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_11OC5.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_13PLJ.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_PW2O.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_11GS4.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_11H98.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_XPT6.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_144GN.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_WQUQ.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_U3ZN.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_OHPK.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_U3ZM.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_OHPM.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_OHPL.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_U3ZH.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_OHPN.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_U3ZG.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_ZXG5.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_ZYT6.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_SJXC.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_13O61.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_139UW.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_ZDTS.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_ZDTT.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_S32W.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_11GSO.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_PX3G.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_RUSQ.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_13PL7.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_13PL6.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_ZU9S.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_R55C.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_R55D.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_R55E.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_R55F.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_R55G.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_RN64.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_QCQG.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_VUSG.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_RVPU.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_S95S.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_ZYFD.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_ZYFG.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_RVPV.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_ZYFC.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_13S86.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_1212Z.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_XMD1.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_XMD3.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_QLQW.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_13OVL.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_14AS3.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_13OVH.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_13OVI.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_13OVJ.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_13OVK.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_139TS.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_13CIG.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_14ABY.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_WXYG.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_X4LF.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_WY7C.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_14753.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_14E6E.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_Z9EW.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_14E6C.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_ZVP2.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_RM2N.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_U412.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_Q734.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_12BJ1.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_X5EB.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_ZZPT.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_ZZPU.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_145MF.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_WHSB.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_WHSE.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_WWYW.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_145MG.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_11UD2.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_14ASI.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_OOBJ.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_11UD1.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_14B4R.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_132AR.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_1445S.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_QLQ7.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_XMK1.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_XUYS.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_12126.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_ZTSS.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_ZDYS.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_ZUA1.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_XAJ8.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_11ONC.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_133LE.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_ZA64.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_13FHO.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_VUSH.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_YECK.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_XUW1.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_13FHP.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_WOFL.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_X4EP.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_13O21.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_YEC4.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_YEC3.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_11EI6.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_X4EO.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_X15G.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_WOFM.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_13FH7.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_1122O.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_QV44.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_ZYY3.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_S7SF.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_S7SE.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_14ICK.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_14ICL.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_13113.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_13112.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_13111.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_WI4N.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_13N11.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_YJ89.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_13QJC.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_SE5C.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_11GSP.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_12696.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_ZVT2.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_13D11.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_ZVT4.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_Y8E5.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_ZLWG.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_13QIC.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_QVJO.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_ZTX8.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_S4Z8.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_14H4A.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_14C38.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_14C39.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_ZVT3.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_SN8G.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_QVUS.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_Y8E4.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_ZVTK.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_T5JW.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_14DAR.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_14DAQ.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_13N1W.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_113IC.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_Y8LW.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_ZAKK.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_XLM4.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_YJ8A.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_YJ8O.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_13QJ3.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_11XUK.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_YB5K.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_S33H.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_139TT.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_139TU.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_NPJ8.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_S4Q7.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_UPJH.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_X585.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_1339X.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_NPJ7.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_13FLW.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_13FLV.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_11EMC.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_O5YW.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_11VI4.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_Q2AG.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_ZP4G.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_Q2AH.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_Q2AI.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_XQ8I.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_ZQUD.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_11EM3.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_139T8.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_139T4.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_139T6.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_11P7K.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_145LS.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_145LU.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_145LT.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_145LV.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_111VG.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_X261.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_11DYG.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_ZYW4.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_ZAK1.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_ZE7O.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_13W3W.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_S3XE.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_ZZ64.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_W5WG.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_ZEX8.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_QEG5.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_QEG4.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_ZVZP.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_ZVZQ.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_PVOW.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_XUJ4.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_131YS.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_13N2G.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_11ZTT.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_132NY.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_11ZTS.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_X88G.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_ZVZO.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_NL3G.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_XGQ4.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_144FL.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_ZTTD.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_NL3H.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_13JUV.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_QDVN.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_QDVJ.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_1128S.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_13O1R.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_RU72.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_ZQG8.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_14A5H.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_14A5I.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_1269C.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_13CF2.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_13CF3.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_ZYWO.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_T2IS.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_ZPCL.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_VJYA.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_TMZS.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_SUCS.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_WVLH.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_U4B1.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_117YX.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_S7PM.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_117YW.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_REY6.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_UJHI.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_T6MO.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_T6MN.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_ZT9W.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_ZT9X.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_PWCY.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_11DZ1.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_11OF3.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_13RTK.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_13RTJ.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_S341.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_Y9LG.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_WZTO.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_Z93T.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_UPK5.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_Z93S.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_X638.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_12KS4.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_SIU8.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_WWTW.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_WL46.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_SIU7.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_SNMC.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_ZF28.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_ZF29.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_13CZU.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_13CZV.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_XMD2.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_YBZK.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_14E1K.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_Y8DK.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_QV31.txt
# ../data/Donor_Metadata_Enhanced/donor_meta_TSE9.txt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-49a48e330911> in <module>()
# ----> 1 multi_matrix, point_ID, point_sex, point_age, point_tissue, point_tissue_group = construct_matrix()
#
# <ipython-input-8-e2c4bf213302> in construct_matrix(spec_donors, reject_donors, donor_sex, donor_age, spec_tissues, reject_tissues, top_tissues, min_tissue_count)
#     122         donorfile.close()
#     123         # concatenate donor matrices
# --> 124         multi_matrix = np.concatenate((multi_matrix,donor_matrix),axis=1)
#     125     multi_matrix = np.delete(multi_matrix,0,1)
#     126
#
# KeyboardInterrupt:
