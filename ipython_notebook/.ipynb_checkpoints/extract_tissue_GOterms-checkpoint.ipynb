# %%
# %matplotlib inline  
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import goatools

# %%
# extract the relevent tissue types
tissues = {}
inputFilename = '../data/Tissue_Name_Mappings.csv' # manually curated by Nico
inputFile = open(inputFilename)
atLine = 0
for line in inputFile:
    str_list = line.split(',')[1:]
    for term in str_list:
        if term == '' or term == '\r\n':
            continue
        else:
            term = term.split('\r\n')[0] # to avoid end of string in the last term
            tissues[term] = int(term.split('(')[1].split(')')[0])
inputFile.close()

# extract the relevant GO terms
GO_list = {}
inputFilename = '../data/BTO_GO.csv'
inputFile = open(inputFilename)
atLine = 0
skipLines = 2
for line in inputFile:
    if atLine < skipLines:
        atLine += 1
        continue
    str_list = line.split(',')[1:]
    tissue = str_list[0]
    if tissue in tissues:
        for term in str_list[1:]:
            if term == '' or term == '\r\n':
                continue
            else: 
                term = term.split('\r\n')[0] # to avoid end of string in the last term
                if term not in GO_list:
                    GO_list[term] = []       
                else:
                    GO_list[term].append(tissue)
                    # print tissue, term
inputFile.close()
print 'Number of tissues in BTO : ' + str(len(tissues))
print 'Number of GO terms       : ' + str(len(GO_list))
# Out:
# heart (337) GO:0060976
# heart (337) GO:0060978
# heart (337) GO:0003150
# heart (337) GO:0003169
# heart (337) GO:0003149
# heart (337) GO:0003244
# heart (337) GO:0003243
# heart (337) GO:0060977
# heart (337) GO:0060981
# heart (337) GO:0055010
# heart (337) GO:0003201
# heart (337) GO:0060980
# kidney (249) GO:0072109
# kidney (249) GO:0072011
# kidney (249) GO:0072104
# kidney (249) GO:0061247
# kidney (249) GO:0061249
# kidney (249) GO:0072223
# kidney (249) GO:0072264
# kidney (249) GO:0072277
# skeletal muscle (155) GO:0061337
# skeletal muscle (155) GO:0060928
# skeletal muscle (155) GO:0060927
# skeletal muscle (155) GO:0060920
# skeletal muscle (155) GO:0061338
# skeletal muscle (155) GO:0060922
# skeletal muscle (155) GO:0060930
# skeletal muscle (155) GO:0003167
# skeletal muscle (155) GO:0060921
# skeletal muscle (155) GO:0060931
# skeletal muscle (155) GO:0055003
# skeletal muscle (155) GO:0060929
# skeletal muscle (155) GO:0060926
# adrenal gland (61) GO:0003112
# adrenal gland (61) GO:0003065
# adrenal gland (61) GO:0003090
# adrenal gland (61) GO:0003061
# adrenal gland (61) GO:0003059
# adrenal gland (61) GO:0003066
# adrenal gland (61) GO:0003089
# adrenal gland (61) GO:0003111
# adrenal gland (61) GO:0001996
# adrenal gland (61) GO:0003114
# adrenal gland (61) GO:0001997
# adrenal gland (61) GO:0003113
# blood (337) GO:0060844
# blood (337) GO:0002034
# blood (337) GO:0072011
# blood (337) GO:0090049
# blood (337) GO:0060674
